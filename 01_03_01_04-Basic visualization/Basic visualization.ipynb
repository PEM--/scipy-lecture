# %% [markdown]
# `inline` is required for drawning inside the notebook

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1D plotting

# %%
x = np.linspace(0, 3, 20)
y = np.linspace(0, 9, 20)
plt.plot(x, y)
plt.plot(x, y, 'o')
# Not necessary in Jupyter: plt.show()

# %% [markdown]
# ## 2D arrays

# %%
image = np.random.rand(30,30)
plt.imshow(image, cmap=plt.cm.hot)
plt.colorbar()

# %%
# Same with gray color map
plt.imshow(image, cmap=plt.cm.gray)
plt.colorbar()
